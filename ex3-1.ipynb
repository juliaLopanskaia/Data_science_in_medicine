# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2*np.pi, 2*np.pi, 201)


plt.plot(x, np.sin(x))
plt.plot(x, np.sin(x-np.pi/2))
plt.plot(x, 2*np.sin(x-np.pi/2))
plt.plot(x, 2*np.sin(x-np.pi/2)+np.pi)
#plt.plot(x, y2)
